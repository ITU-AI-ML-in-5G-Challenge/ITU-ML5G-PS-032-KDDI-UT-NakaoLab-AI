# %%
import sys
sys.version
# Out:
# '3.7.6 (default, Jan  8 2020, 13:42:34) \n[Clang 4.0.1 (tags/RELEASE_401/final)]'

# %%
import pandas as pd
pd.__version__
# Out:
# '0.24.2'

# %%
import sklearn
sklearn.__version__
# Out:
# '0.23.2'

# %%
import time
import itertools
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier, plot_importance
import numpy as np
from numpy import sort
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import svm

# %%
# dataset path
dataset_path = './csv/diff_dataset.csv'
testset_path = './csv/diff_testset.csv'

# %%
# read dataset
dataset = pd.read_csv(dataset_path)
testset = pd.read_csv(testset_path)

# %%
# drop unnamed column
dataset.drop(columns=['Unnamed: 0'], inplace=True)
testset.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# remove resolve state
data_drop_index = dataset[dataset['v_type_code'] %2 == 0].index.tolist()
dataset.drop(index=data_drop_index, axis=0, inplace=True)
test_drop_index = testset[testset['v_type_code'] %2 == 0].index.tolist()
testset.drop(index=test_drop_index, axis=0, inplace=True)

# data_57 = dataset[dataset['v_type_code'].isin([5,7])].index.tolist()
# dataset.drop(index=data_57, axis=0, inplace=True)

# test_57 = testset[testset['v_type_code'].isin([5,7])].index.tolist()
# testset.drop(index=test_57, axis=0, inplace=True)

# %%
# Try to combine 5 and 7 into one type.
dataset['v_type_code'] = dataset['v_type_code'].apply(lambda x: 57 if x == 5 or x == 7 else x)
testset['v_type_code'] = testset['v_type_code'].apply(lambda x: 57 if x == 5 or x == 7 else x)

# %%
print('dataset:')
print(dataset.shape)
print('testset:')
print(testset.shape)

column = dataset.columns
# Out:
# dataset:
# (930, 997)
# testset:
# (840, 997)

# %%
X_train = dataset[column[:-1]]
X_test = testset[column[:-1]]
y_train = dataset[column[-1]]
y_test = testset[column[-1]]

X = pd.concat([X_train, X_test], axis=0, ignore_index=True, sort=False)
Y = pd.concat([y_train, y_test], axis=0, ignore_index=True, sort=False)
#     X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
print(X.shape, Y.shape)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1770, 996) (1770,)
# (930, 996) (930,)
# (840, 996) (840,)

# %%
ss = StandardScaler()
std_X_train = ss.fit_transform(X_train)
std_X_test = ss.fit_transform(X_test)

# %%
# XGBoost
def xgboost(X_train, y_train, X_test, y_test, show=False, plt_show=True):
    last_time = time.time()
    xgb = XGBClassifier(n_estimators=100, objective='multi:softprob', num_class=5, random_state=0)
    xgb.fit(X_train, y_train)
    middle_time = time.time()
    y_pred = xgb.predict(X_test)
    current_time = time.time()
    accuracy_score(y_test, y_pred)

#     print("train time： {}".format(middle_time - last_time))
#     print("test time： {}".format(current_time - middle_time))
    if show:
        cm = confusion_matrix(y_test, y_pred)
        report=classification_report(y_test, y_pred, output_dict=True)
        return report

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.4f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="red")
        # color="red" if cm[i, j] > thresh else "black")
    # plt.set_tight_layout(True)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
model = XGBClassifier(importance_type='gain',n_estimators=100)
model.fit(X, Y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
_, ax = plt.subplots(figsize=(20, 100))
plt.rc('font', size=14)
plt.rc('axes', labelsize=14) 
plot_importance(model, ax=ax, max_num_features=200, importance_type='gain')
plt.show()

# %%
im=pd.DataFrame({'importance':model.feature_importances_,'var':X.columns})
im=im.sort_values(by='importance',ascending=False)
im.to_csv("feature_important_data_XG_1015.csv")

# %%
thresholds = sort(model.feature_importances_)[-200:]
print(thresholds)
# Out:
# [0.00067739 0.00068989 0.00069681 0.00070137 0.00070513 0.00070932
#  0.0007127  0.00071757 0.00072783 0.0007376  0.00075725 0.00075987
#  0.00078066 0.00078761 0.00079499 0.00079642 0.00080353 0.00080576
#  0.0008178  0.00082203 0.00083998 0.00084352 0.00084359 0.00084675
#  0.000857   0.00087472 0.00088903 0.00089168 0.0008946  0.00089844
#  0.00091002 0.00091077 0.0009279  0.00093492 0.00093719 0.00094159
#  0.00095465 0.00095553 0.0009758  0.00100338 0.00101296 0.00101834
#  0.00101927 0.0010292  0.00102925 0.00103081 0.0010448  0.00105241
#  0.00106587 0.00107128 0.00107262 0.00107534 0.00108742 0.00108951
#  0.00109302 0.00110083 0.00110913 0.00110934 0.00111386 0.00114796
#  0.00116836 0.00117042 0.00117992 0.00119349 0.00121525 0.00122226
#  0.00122564 0.00123148 0.00127504 0.00131969 0.00134862 0.00144684
#  0.00145469 0.0014648  0.00148592 0.00148864 0.00149682 0.00155096
#  0.00155264 0.00158837 0.00159922 0.00160554 0.00161475 0.00161686
#  0.00162107 0.00163461 0.00166905 0.00167031 0.00167572 0.00168757
#  0.00171855 0.00172106 0.0017226  0.00173779 0.00174047 0.00174476
#  0.00176565 0.00176803 0.00185239 0.00185658 0.00187803 0.00188438
#  0.00189167 0.0018918  0.00192082 0.00192287 0.00195072 0.00196557
#  0.00196602 0.00196745 0.00197091 0.00197414 0.00197606 0.00199971
#  0.00201906 0.00204697 0.00215519 0.00217321 0.00220194 0.00221733
#  0.00232084 0.00236079 0.0023911  0.00240714 0.00241703 0.00242985
#  0.00244272 0.00247397 0.00254125 0.00261362 0.00271949 0.00289964
#  0.00291802 0.00300009 0.00307497 0.00309409 0.00313281 0.00317219
#  0.00328067 0.00330063 0.00339742 0.00350445 0.00352663 0.00358448
#  0.00364501 0.00365702 0.00376668 0.0038914  0.00419602 0.00423359
#  0.00430066 0.00434451 0.00442342 0.00442427 0.00444066 0.00448466
#  0.00454404 0.00472021 0.00477575 0.00482095 0.0050639  0.00507796
#  0.00508931 0.00515489 0.00516715 0.0052579  0.00540809 0.00552308
#  0.00569309 0.00586208 0.00594773 0.00626069 0.00691479 0.00723822
#  0.00743216 0.00751951 0.00800757 0.00820121 0.00836241 0.00878097
#  0.0090358  0.00966603 0.00971493 0.0103501  0.01179357 0.01192256
#  0.01245479 0.01313786 0.01374193 0.01420715 0.02100425 0.02124248
#  0.02303768 0.02799016 0.03105561 0.04492054 0.05688684 0.05920639
#  0.06458369 0.06891287]

# %%
list_1=[]
list_3=[]
list_5_7=[]
# list_5=[]
# list_7=[]
list_9=[]
list_11=[]
list_acc=[]

for thresh in thresholds:
    selection = SelectFromModel(model, threshold=thresh, prefit=True)
    select_X_train = selection.transform(X_train)
    select_X_test = selection.transform(X_test)
    # 格式：'1': {'precision': 0.9824561403508771, 'recall': 0.875, 'f1-score': 0.9256198347107438, 'support': 64}
    report = xgboost(select_X_train, y_train, select_X_test, y_test,show=True)
    list_1.append(report['1']['precision'])
    list_3.append(report['3']['precision'])
#     list_5.append(report['5']['precision'])
#     list_7.append(report['7']['precision'])
    list_5_7.append(report['57']['precision'])
    list_9.append(report['9']['precision'])
    list_11.append(report['11']['precision'])
    list_acc.append(report['accuracy'])
    print("Thresh=%.4f, n=%d, Accuracy: %.2f%%" % (thresh, select_X_train.shape[1], report['accuracy'] * 100.0))
# Out:
# Thresh=0.0007, n=200, Accuracy: 88.81%
# Thresh=0.0007, n=199, Accuracy: 88.81%
# Thresh=0.0007, n=198, Accuracy: 89.05%
# Thresh=0.0007, n=197, Accuracy: 89.17%
# Thresh=0.0007, n=196, Accuracy: 88.81%
# Thresh=0.0007, n=195, Accuracy: 89.29%
# Thresh=0.0007, n=194, Accuracy: 89.76%
# Thresh=0.0007, n=193, Accuracy: 88.69%
# Thresh=0.0007, n=192, Accuracy: 88.69%
# Thresh=0.0007, n=191, Accuracy: 89.05%
# Thresh=0.0008, n=190, Accuracy: 88.81%
# Thresh=0.0008, n=189, Accuracy: 88.69%
# Thresh=0.0008, n=188, Accuracy: 89.05%
# Thresh=0.0008, n=187, Accuracy: 88.81%
# Thresh=0.0008, n=186, Accuracy: 89.29%
# Thresh=0.0008, n=185, Accuracy: 89.40%
# Thresh=0.0008, n=184, Accuracy: 88.93%
# Thresh=0.0008, n=183, Accuracy: 88.93%
# Thresh=0.0008, n=182, Accuracy: 88.93%
# Thresh=0.0008, n=181, Accuracy: 89.17%
# Thresh=0.0008, n=180, Accuracy: 89.40%
# Thresh=0.0008, n=179, Accuracy: 89.52%
# Thresh=0.0008, n=178, Accuracy: 88.81%
# Thresh=0.0008, n=177, Accuracy: 89.05%
# Thresh=0.0009, n=176, Accuracy: 89.40%
# Thresh=0.0009, n=175, Accuracy: 88.57%
# Thresh=0.0009, n=174, Accuracy: 88.93%
# Thresh=0.0009, n=173, Accuracy: 89.05%
# Thresh=0.0009, n=172, Accuracy: 89.17%
# Thresh=0.0009, n=171, Accuracy: 89.40%
# Thresh=0.0009, n=170, Accuracy: 89.17%
# Thresh=0.0009, n=169, Accuracy: 89.05%
# Thresh=0.0009, n=168, Accuracy: 89.29%
# Thresh=0.0009, n=167, Accuracy: 89.17%
# Thresh=0.0009, n=166, Accuracy: 89.17%
# Thresh=0.0009, n=165, Accuracy: 89.17%
# Thresh=0.0010, n=164, Accuracy: 89.40%
# Thresh=0.0010, n=163, Accuracy: 89.29%
# Thresh=0.0010, n=162, Accuracy: 89.64%
# Thresh=0.0010, n=161, Accuracy: 89.52%
# Thresh=0.0010, n=160, Accuracy: 89.40%
# Thresh=0.0010, n=159, Accuracy: 89.40%
# Thresh=0.0010, n=158, Accuracy: 89.52%
# Thresh=0.0010, n=157, Accuracy: 89.40%
# Thresh=0.0010, n=156, Accuracy: 88.93%
# Thresh=0.0010, n=155, Accuracy: 88.93%
# Thresh=0.0010, n=154, Accuracy: 88.81%
# Thresh=0.0011, n=153, Accuracy: 88.81%
# Thresh=0.0011, n=152, Accuracy: 89.05%
# Thresh=0.0011, n=151, Accuracy: 89.05%
# Thresh=0.0011, n=150, Accuracy: 89.29%
# Thresh=0.0011, n=149, Accuracy: 89.29%
# Thresh=0.0011, n=148, Accuracy: 89.17%
# Thresh=0.0011, n=147, Accuracy: 89.40%
# Thresh=0.0011, n=146, Accuracy: 89.29%
# Thresh=0.0011, n=145, Accuracy: 89.29%
# Thresh=0.0011, n=144, Accuracy: 89.29%
# Thresh=0.0011, n=143, Accuracy: 89.76%
# Thresh=0.0011, n=142, Accuracy: 89.76%
# Thresh=0.0011, n=141, Accuracy: 88.93%
# Thresh=0.0012, n=140, Accuracy: 89.05%
# Thresh=0.0012, n=139, Accuracy: 89.05%
# Thresh=0.0012, n=138, Accuracy: 89.17%
# Thresh=0.0012, n=137, Accuracy: 88.93%
# Thresh=0.0012, n=136, Accuracy: 89.17%
# Thresh=0.0012, n=135, Accuracy: 89.17%
# Thresh=0.0012, n=134, Accuracy: 88.93%
# Thresh=0.0012, n=133, Accuracy: 89.29%
# Thresh=0.0013, n=132, Accuracy: 88.93%
# Thresh=0.0013, n=131, Accuracy: 88.81%
# Thresh=0.0013, n=130, Accuracy: 88.81%
# Thresh=0.0014, n=129, Accuracy: 89.29%
# Thresh=0.0015, n=128, Accuracy: 89.76%
# Thresh=0.0015, n=127, Accuracy: 89.76%
# Thresh=0.0015, n=126, Accuracy: 89.52%
# Thresh=0.0015, n=125, Accuracy: 89.52%
# Thresh=0.0015, n=124, Accuracy: 89.52%
# Thresh=0.0016, n=123, Accuracy: 89.29%
# Thresh=0.0016, n=122, Accuracy: 90.00%
# Thresh=0.0016, n=121, Accuracy: 89.52%
# Thresh=0.0016, n=120, Accuracy: 90.00%
# Thresh=0.0016, n=119, Accuracy: 89.52%
# Thresh=0.0016, n=118, Accuracy: 90.12%
# Thresh=0.0016, n=117, Accuracy: 90.12%
# Thresh=0.0016, n=116, Accuracy: 89.52%
# Thresh=0.0016, n=115, Accuracy: 89.52%
# Thresh=0.0017, n=114, Accuracy: 89.40%
# Thresh=0.0017, n=113, Accuracy: 89.52%
# Thresh=0.0017, n=112, Accuracy: 89.76%
# Thresh=0.0017, n=111, Accuracy: 89.88%
# Thresh=0.0017, n=110, Accuracy: 89.52%
# Thresh=0.0017, n=109, Accuracy: 89.64%
# Thresh=0.0017, n=108, Accuracy: 89.52%
# Thresh=0.0017, n=107, Accuracy: 89.64%
# Thresh=0.0017, n=106, Accuracy: 89.17%
# Thresh=0.0017, n=105, Accuracy: 90.24%
# Thresh=0.0018, n=104, Accuracy: 89.88%
# Thresh=0.0018, n=103, Accuracy: 90.00%
# Thresh=0.0019, n=102, Accuracy: 89.52%
# Thresh=0.0019, n=101, Accuracy: 89.64%
# Thresh=0.0019, n=100, Accuracy: 89.52%
# Thresh=0.0019, n=99, Accuracy: 89.88%
# Thresh=0.0019, n=98, Accuracy: 89.64%
# Thresh=0.0019, n=97, Accuracy: 90.00%
# Thresh=0.0019, n=96, Accuracy: 90.12%
# Thresh=0.0019, n=95, Accuracy: 89.52%
# Thresh=0.0020, n=94, Accuracy: 89.76%
# Thresh=0.0020, n=93, Accuracy: 89.52%
# Thresh=0.0020, n=92, Accuracy: 89.76%
# Thresh=0.0020, n=91, Accuracy: 89.64%
# Thresh=0.0020, n=90, Accuracy: 89.52%
# Thresh=0.0020, n=89, Accuracy: 89.76%
# Thresh=0.0020, n=88, Accuracy: 90.24%
# Thresh=0.0020, n=87, Accuracy: 90.12%
# Thresh=0.0020, n=86, Accuracy: 89.40%
# Thresh=0.0020, n=85, Accuracy: 89.76%
# Thresh=0.0022, n=84, Accuracy: 90.00%
# Thresh=0.0022, n=83, Accuracy: 90.00%
# Thresh=0.0022, n=82, Accuracy: 89.88%
# Thresh=0.0022, n=81, Accuracy: 90.00%
# Thresh=0.0023, n=80, Accuracy: 90.12%
# Thresh=0.0024, n=79, Accuracy: 89.88%
# Thresh=0.0024, n=78, Accuracy: 90.83%
# Thresh=0.0024, n=77, Accuracy: 90.36%
# Thresh=0.0024, n=76, Accuracy: 90.60%
# Thresh=0.0024, n=75, Accuracy: 90.95%
# Thresh=0.0024, n=74, Accuracy: 90.71%
# Thresh=0.0025, n=73, Accuracy: 90.71%
# Thresh=0.0025, n=72, Accuracy: 90.83%
# Thresh=0.0026, n=71, Accuracy: 91.07%
# Thresh=0.0027, n=70, Accuracy: 90.24%
# Thresh=0.0029, n=69, Accuracy: 90.12%
# Thresh=0.0029, n=68, Accuracy: 91.31%
# Thresh=0.0030, n=67, Accuracy: 90.83%
# Thresh=0.0031, n=66, Accuracy: 90.95%
# Thresh=0.0031, n=65, Accuracy: 90.71%
# Thresh=0.0031, n=64, Accuracy: 91.07%
# Thresh=0.0032, n=63, Accuracy: 90.83%
# Thresh=0.0033, n=62, Accuracy: 90.71%
# Thresh=0.0033, n=61, Accuracy: 90.95%
# Thresh=0.0034, n=60, Accuracy: 90.95%
# Thresh=0.0035, n=59, Accuracy: 91.55%
# Thresh=0.0035, n=58, Accuracy: 91.67%
# Thresh=0.0036, n=57, Accuracy: 91.67%
# Thresh=0.0036, n=56, Accuracy: 91.55%
# Thresh=0.0037, n=55, Accuracy: 91.43%
# Thresh=0.0038, n=54, Accuracy: 91.43%
# Thresh=0.0039, n=53, Accuracy: 91.19%
# Thresh=0.0042, n=52, Accuracy: 91.43%
# Thresh=0.0042, n=51, Accuracy: 91.07%
# Thresh=0.0043, n=50, Accuracy: 90.95%
# Thresh=0.0043, n=49, Accuracy: 91.07%
# Thresh=0.0044, n=48, Accuracy: 91.43%
# Thresh=0.0044, n=47, Accuracy: 91.19%
# Thresh=0.0044, n=46, Accuracy: 91.07%
# Thresh=0.0045, n=45, Accuracy: 91.31%
# Thresh=0.0045, n=44, Accuracy: 91.07%
# Thresh=0.0047, n=43, Accuracy: 90.95%
# Thresh=0.0048, n=42, Accuracy: 90.60%
# Thresh=0.0048, n=41, Accuracy: 90.95%
# Thresh=0.0051, n=40, Accuracy: 90.95%
# Thresh=0.0051, n=39, Accuracy: 91.07%
# Thresh=0.0051, n=38, Accuracy: 90.71%
# Thresh=0.0052, n=37, Accuracy: 89.88%
# Thresh=0.0052, n=36, Accuracy: 90.48%
# Thresh=0.0053, n=35, Accuracy: 90.60%
# Thresh=0.0054, n=34, Accuracy: 89.76%
# Thresh=0.0055, n=33, Accuracy: 89.88%
# Thresh=0.0057, n=32, Accuracy: 89.40%
# Thresh=0.0059, n=31, Accuracy: 89.88%
# Thresh=0.0059, n=30, Accuracy: 89.40%
# Thresh=0.0063, n=29, Accuracy: 89.76%
# Thresh=0.0069, n=28, Accuracy: 89.29%
# Thresh=0.0072, n=27, Accuracy: 88.57%
# Thresh=0.0074, n=26, Accuracy: 88.69%
# Thresh=0.0075, n=25, Accuracy: 89.52%
# Thresh=0.0080, n=24, Accuracy: 89.52%
# Thresh=0.0082, n=23, Accuracy: 89.05%
# Thresh=0.0084, n=22, Accuracy: 88.93%
# Thresh=0.0088, n=21, Accuracy: 89.29%
# Thresh=0.0090, n=20, Accuracy: 89.52%
# Thresh=0.0097, n=19, Accuracy: 89.52%
# Thresh=0.0097, n=18, Accuracy: 89.52%
# Thresh=0.0104, n=17, Accuracy: 89.05%
# Thresh=0.0118, n=16, Accuracy: 89.17%
# Thresh=0.0119, n=15, Accuracy: 88.93%
# Thresh=0.0125, n=14, Accuracy: 89.05%
# Thresh=0.0131, n=13, Accuracy: 89.29%
# Thresh=0.0137, n=12, Accuracy: 88.69%
# Thresh=0.0142, n=11, Accuracy: 87.98%
# Thresh=0.0210, n=10, Accuracy: 87.74%
# Thresh=0.0212, n=9, Accuracy: 87.50%
# Thresh=0.0230, n=8, Accuracy: 87.50%
# Thresh=0.0280, n=7, Accuracy: 87.98%
# Thresh=0.0311, n=6, Accuracy: 81.55%
# Thresh=0.0449, n=5, Accuracy: 81.55%
# Thresh=0.0569, n=4, Accuracy: 69.88%
# Thresh=0.0592, n=3, Accuracy: 67.86%
# Thresh=0.0646, n=2, Accuracy: 57.14%
# Thresh=0.0689, n=1, Accuracy: 53.10%

# %%
print(len(list_1))
# Out:
# 200

# %%
# X_train result
x_n = [str(200-x) for x in range(200)]
plt.figure(figsize=(20, 6))
plt.rc('font', size=14)
plt.rc('axes', labelsize=14) 
plt.plot(x_n,list_acc,'r--',label='Accuracy')
plt.plot(x_n,list_1,'y',label='Type1 Node Down')
plt.plot(x_n,list_3,'b',label='Type3 Interface Down')
# plt.plot(x_n,list_5,'g',label='Type5 Packet Loss')
# plt.plot(x_n,list_7,'k',label='Type7 Packet Delay')
plt.plot(x_n,list_5_7,'g',label='Type5 & 7 Packet Loss & Delay')
plt.plot(x_n,list_9,'c',label='Type9 BGP Injection')
plt.plot(x_n,list_11,'m',label='Type11 BGP Hijack')
plt.legend(loc='lower left')
plt.title('The accuracy of the number of different features')
plt.xlabel('The number of features')
plt.ylabel('Accuracy(%)')
plt.xticks(np.arange(200,-5,-5))
plt.show()

# %%
print(list_acc[143])
print(list_1[143])
print(list_3[143])
print(list_5_7[143])
print(list_9[143])
print(list_11[143])
# Out:
# 0.9166666666666666
# 0.9833333333333333
# 0.9264705882352942
# 0.8554778554778555
# 0.9871794871794872
# 1.0

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=30)     #加载PCA算法，设置降维后主成分数目为自动
reduced_X=pca.fit_transform(X)#对样本进行降维

# %%
# random forest
def random_forest(X_train, y_train, X_test, y_test, show=False):
    last_time = time.time()
    rf = RandomForestClassifier(n_estimators=100, max_depth=None, min_samples_split=2, random_state=0)

    rf.fit(X_train, y_train)
    middle_time = time.time()

    y_pred = rf.predict(X_test)

    current_time = time.time()

    print("Accuracy: %.2f"% accuracy_score(y_test, y_pred))

    print("训练耗时： {}".format(middle_time - last_time))
    print("测试耗时： {}".format(current_time - middle_time))
    if show:
        cm = confusion_matrix(y_test, y_pred)
        print('confusion matrix rf:')
        print(cm)
        print('classification report rf:')
        print(classification_report(y_test, y_pred))

        plot_confusion_matrix(cm, classes=['1', '3', '9', '11'],
                              normalize=True, title='Normalized confusion matrix')

        plt.show()

# %%
reduced_X_train, reduced_X_test, reduced_y_train, reduced_y_test = train_test_split(reduced_X, Y, test_size=0.7)
random_forest(reduced_X_train, reduced_y_train, reduced_X_test, reduced_y_test, show=True)
# Out:
# Accuracy: 0.79
# 训练耗时： 0.16594672203063965
# 测试耗时： 0.012247085571289062
# confusion matrix rf:
# [[ 63   0   0   2]
#  [  8  78  35   0]
#  [  1  18 158   2]
#  [  1   4  40 110]]
# classification report rf:
#               precision    recall  f1-score   support
#
#            1       0.86      0.97      0.91        65
#            3       0.78      0.64      0.71       121
#            9       0.68      0.88      0.77       179
#           11       0.96      0.71      0.82       155
#
#     accuracy                           0.79       520
#    macro avg       0.82      0.80      0.80       520
# weighted avg       0.81      0.79      0.79       520
#
# Normalized confusion matrix
# [[0.96923077 0.         0.         0.03076923]
#  [0.0661157  0.6446281  0.2892562  0.        ]
#  [0.00558659 0.10055866 0.88268156 0.01117318]
#  [0.00645161 0.02580645 0.25806452 0.70967742]]
